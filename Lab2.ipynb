# %%
s = "Programming"
print(len(s))
print(s[0])
# Out:
# 11
# P

# %%
s1 = "Hello"
s2 = "World"
print(s1 + " " + s2)
# Out:
# Hello World

# %%
text = "Python"
print(text[-1])
# Out:
# n

# %%
s = "Artificial"
print(s.replace("Art", ""))
# Out:
# ificial

# %%
word = "Code"
print(word[::-1])
# Out:
# edoC

# %%
s = "abcdefgh"
print(s[::2])
# Out:
# aceg

# %%
text = "data"
print(text.upper(), text.lower())
# Out:
# DATA data

# %%
s = "Python-R-Java"
print(s.split("-"))
# Out:
# ['Python', 'R', 'Java']

# %%
ad = "Ayxan"
yas = 25
print(f"{ad} {yas} yaşındadır")
# Out:
# Ayxan 25 yaşındadır

# %%
s = "salam-dunya"
print(s.replace("-", " "))
# Out:
# salam dunya
